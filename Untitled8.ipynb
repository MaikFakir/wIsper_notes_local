# %% [markdown]
# <a href="https://colab.research.google.com/github/MaikFakir/wIsper_notes_local/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 53.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=95575a979af9172b5f25d4ece9368ad48e1dc4c5bf1ac4b69f9fa110ea45ea45
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-mrjpohir
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-mrjpohir
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
pip install --upgrade --no-deps --force-reinstall git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-xkr3iybo
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-xkr3iybo
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=3dffb661125308977284dd058734fa8804c701be90b7aac5fa594078fe17bf6a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-neo0q9qi/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...
#   Attempting uninstall: openai-whisper
#     Found existing installation: openai-whisper 20250625
#     Uninstalling openai-whisper-20250625:
#       Successfully uninstalled openai-whisper-20250625
# ...

# %%
'''!pip install -q faster-whisper gradio ffmpeg

from faster_whisper import WhisperModel
import gradio as gr

# Cargar modelo tiny optimizado
model = WhisperModel("turbo", device="cuda", compute_type="float16")

def transcribir(audio):
    if audio is None:
        return "No se recibió audio."

    segments, info = model.transcribe(audio, language="es")
    text = " ".join([seg.text for seg in segments])
    return text

with gr.Blocks() as demo:
    gr.Markdown("## 🎙️ Transcriptor rápido con Faster-Whisper (Tiny, Español)")
    with gr.Row():
        mic = gr.Audio(sources=["microphone"], type="filepath", label="🎤 Graba tu audio")
        text_box = gr.Textbox(label="📝 Transcripción", lines=15)
    mic.change(transcribir, inputs=mic, outputs=text_box)

demo.launch(share=True)

# %%
# --- 1. INSTALACIONES E IMPORTACIONES ---
# !pip install -q faster-whisper gradio resemblyzer librosa ffmpeg-python scikit-learn

from faster_whisper import WhisperModel
import gradio as gr
from resemblyzer import VoiceEncoder
import numpy as np
import librosa
from sklearn.cluster import DBSCAN
import torch

# --- 2. CARGA DE MODELOS ---

# Determina el dispositivo a usar
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
COMPUTE_TYPE = "float16" if torch.cuda.is_available() else "int8"

# Cargar modelo Whisper. 'base' es un buen equilibrio entre velocidad y precisión para timestamps.
# 'turbo' no es un tamaño de modelo estándar, lo cambiamos por 'base'.
transcription_model = WhisperModel("turbo", device=DEVICE, compute_type=COMPUTE_TYPE)

# Cargar encoder de voces. Es recomendable usar CPU para evitar conflictos de VRAM.
voice_encoder = VoiceEncoder(device="cpu")


# --- 3. FUNCIÓN PRINCIPAL DE PROCESAMIENTO ---

def transcribir_con_diarizacion(audio_path):
    if audio_path is None:
        return "No se recibió audio. Por favor, graba algo."

    # 1️⃣ Cargar audio UNA SOLA VEZ
    # Optimizacion: Cargamos el audio con librosa y lo pasamos como un array de numpy a Whisper.
    # Esto evita que el archivo se lea del disco dos veces.
    wav, sr = librosa.load(audio_path, sr=16000)

    # 2️⃣ Transcripción con Whisper
    # Pasamos el array de numpy 'wav' directamente al modelo.
    segments_generator, info = transcription_model.transcribe(wav, language="es")

    # --- LA CORRECCIÓN CLAVE ---
    # Convertimos el generador a una lista para poder acceder a su longitud y elementos múltiples veces.
    segments = list(segments_generator)

    if not segments:
        return "No se pudo transcribir el audio (posiblemente silencio)."

    # 3️⃣ Extraer embeddings de voz de cada segmento
    embeddings = []
    valid_segments = []
    for seg in segments:
        start_sample = int(seg.start * sr)
        end_sample = int(seg.end * sr)
        segment_wav = wav[start_sample:end_sample]

        # Nos aseguramos de que el segmento de audio no sea demasiado corto para el encoder.
        if len(segment_wav) < 400: # El encoder necesita al menos 400 muestras (25ms)
            continue

        emb = voice_encoder.embed_utterance(segment_wav)
        embeddings.append(emb)
        valid_segments.append(seg)

    # Convertimos a numpy array para el clustering
    embeddings = np.array(embeddings)

    if len(embeddings) == 0:
        # Si no se pudo obtener ningún embedding, devolvemos la transcripción simple
        return " ".join([s.text for s in segments])

    # 4️⃣ Clustering de hablantes con DBSCAN
    # El valor 'eps' es el más importante a ajustar. Un valor más bajo crea más clusters (más hablantes).
    # Un valor más alto agrupa más voces juntas. 0.5 es un buen punto de partida.
    clustering = DBSCAN(eps=0.5, min_samples=1, metric="cosine").fit(embeddings)
    labels = clustering.labels_

    # 5️⃣ Construir la transcripción final formateada
    transcripcion = ""
    current_speaker_label = -1 # Empezamos con una etiqueta inválida

    for i, seg in enumerate(valid_segments):
        speaker_label = labels[i]

        # Si el hablante cambia, guardamos el párrafo anterior y empezamos uno nuevo.
        if speaker_label != current_speaker_label:
            if current_speaker_label != -1:
                # Añade el párrafo del hablante anterior al resultado final
                speaker_name = f"Hablante {current_speaker_label + 1}"
                transcripcion += f"**{speaker_name}:** {current_text.strip()}\n\n"

            # Resetea para el nuevo hablante
            current_speaker_label = speaker_label
            current_text = seg.text
        else:
            # Si es el mismo hablante, simplemente añade el texto
            current_text += " " + seg.text

    # Asegurarse de agregar el último párrafo que quedó en el buffer
    if current_speaker_label != -1:
        speaker_name = f"Hablante {current_speaker_label + 1}"
        transcripcion += f"**{speaker_name}:** {current_text.strip()}\n\n"

    return transcripcion.strip()

# --- 4. INTERFAZ DE GRADIO ---

with gr.Blocks(theme=gr.themes.Soft()) as demo:
    gr.Markdown("## 🎙️ Transcriptor con Diarización (Resemblyzer + DBSCAN)")
    gr.Markdown("Graba una conversación. El sistema transcribirá y agrupará los segmentos por hablante.")

    with gr.Row():
        mic = gr.Audio(sources=["microphone"], type="filepath", label="🎤 Graba tu audio aquí")

    with gr.Row():
        text_box = gr.Textbox(label="📝 Transcripción con Hablantes", lines=20, interactive=False)

    mic.change(transcribir_con_diarizacion, inputs=mic, outputs=text_box)

demo.launch(share=True, debug=True)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.3 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
# After generating your PAT and storing it as a Colab Secret named 'GITHUB_TOKEN'

import os
from google.colab import userdata

github_username = "MaikFakir" # Replace with your GitHub username
repository_name = "wIsper_notes_local" # Replace with your repository name
github_token = userdata.get('GITHUB_TOKEN')

if github_token:
    # Construct the remote URL with the token
    remote_url = f"https://{github_username}:{github_token}@github.com/{github_username}/{repository_name}.git"

    # Now modify the git push command in the next cell to use this remote_url
    # For example: !git push "{remote_url}" main

else:
    print("GitHub token not found in Colab Secrets. Please add it.")

# %%
# !echo "# wIsper_notes_local" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/MaikFakir/wIsper_notes_local.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# [main b1fc854] first commit
#  1 file changed, 1 insertion(+)
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Stage all changes
# !git add .

# Commit changes
# !git commit -m "Update project from Colab" # You can change the commit message

# Push changes using the remote_url from the previous cell
if 'remote_url' in locals():
  # !git push "{remote_url}" main
else:
  print("Error: remote_url not found. Please run the cell to get the GitHub token first.")
# Out:
# On branch main
# nothing to commit, working tree clean
# Enumerating objects: 40, done.
# Counting objects: 100% (40/40), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (30/30), done.
# Writing objects: 100% (40/40), 8.42 MiB | 2.78 MiB/s, done.
# Total 40 (delta 9), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (9/9), done.
# To https://github.com/MaikFakir/wIsper_notes_local.git
#  * [new branch]      main -> main
